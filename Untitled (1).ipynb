# %% [markdown]
# # Assignment

# %%
import pandas as pd
import numpy as np

# %%
# per type => avg total, HP, Attack, Defense
# Ex:          total  attack defense
# Grass      :  20     18      7
# Fire       :  21     19      8

# => read in dataset
# => What types are there
# => Drop unecessary databases
# => Split up into separate databases
# => Calculate mean of variables
# => Save them into a newdataframe
# => Combine all dataframes back together

# %%
# => read in dataset
pok_df = pd.read_csv("../../code/data ingestion/Pokemon.csv")

# %%
pok_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# => What types are there
#pok_df
unique_types = pok_df.loc[:,"Type 1"].unique()
unique_types
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# => Drop unecessary databases
datasets = []
metrics_df = pok_df.loc[:, ["Type 1", "Total", "HP", "Attack", "Defense"]]
for type in unique_types:
    datasets.append(type + "_df")
    
# => Split up into separate databases
file = {}
for type in unique_types:
    file[type] = metrics_df.loc[metrics_df["Type 1"] == type, :]

# %%
file
# Out:
# {'Grass':     Type 1  Total   HP  Attack  Defense
#  0    Grass    318   45      49       49
#  1    Grass    405   60      62       63
#  2    Grass    525   80      82       83
#  3    Grass    625   80     100      123
#  48   Grass    320   45      50       55
#  ..     ...    ...  ...     ...      ...
#  718  Grass    313   56      61       65
#  719  Grass    405   61      78       95
#  720  Grass    530   88     107      122
#  740  Grass    350   66      65       48
#  741  Grass    531  123     100       62
#
#  [70 rows x 5 columns],
#  'Fire':     Type 1  Total   HP  Attack  Defense
#  4     Fire    309   39      52       43
#  5     Fire    405   58      64       58
#  6     Fire    534   78      84       78
#  7     Fire    634   78     130      111
#  8     Fire    634   78     104       78
#  42    Fire    299   38      41       40
#  43    Fire    505   73      76       75
#  63    Fire    350   55      70       45
#  64    Fire    555   90     110       80
# ...

# %%
# => Calculate mean of variables
# => Save them into a newdataframe
# => Combine all dataframes back together
averages = {}
averages_rounded = {}
for x in range(0, len(unique_types)):
    averages_rounded[unique_types[x]] = round(np.mean(file[unique_types[x]].iloc[:,1:]), 0)
    averages[unique_types[x]] = np.mean(file[unique_types[x]].iloc[:,1:])

# %%
averages
# Out:
# {'Grass': Total      421.142857
#  HP          67.271429
#  Attack      73.214286
#  Defense     70.800000
#  dtype: float64,
#  'Fire': Total      458.076923
#  HP          69.903846
#  Attack      84.769231
#  Defense     67.769231
#  dtype: float64,
#  'Water': Total      430.455357
#  HP          72.062500
#  Attack      74.151786
#  Defense     72.946429
#  dtype: float64,
#  'Bug': Total      378.927536
#  HP          56.884058
#  Attack      70.971014
#  Defense     70.724638
#  dtype: float64,
#  'Normal': Total      401.683673
#  HP          77.275510
#  Attack      73.469388
#  Defense     59.846939
#  dtype: float64,
#  'Poison': Total      399.142857
#  HP          67.250000
#  Attack      74.678571
#  Defense     68.821429
#  dtype: float64,
#  'Electric': Total      443.409091
#  HP          59.795455
#  Attack      69.090909
#  Defense     66.295455
#  dtype: float64,
#  'Ground': Total      437.50000
#  HP          73.78125
#  Attack      95.75000
# ...

# %%
# Print the names of the columns.
print ("{:<10} {:<10} {:<10} {:<10} {:<10}".format('Type', 'Avg.Total', 'Avg.HP', 'Avg.Attack', 'Avg.Def'))

# print each data item.
for key, value in averages_rounded.items():
    Type = key
    Total, HP, Attack, Defense = value
    print ("{:<10} {:<10} {:<10} {:<10} {:<10}".format(Type, Total, HP, Attack, Defense))
# Out:
# Type       Avg.Total  Avg.HP     Avg.Attack Avg.Def
# Grass      421.0      67.0       73.0       71.0
# Fire       458.0      70.0       85.0       68.0
# Water      430.0      72.0       74.0       73.0
# Bug        379.0      57.0       71.0       71.0
# Normal     402.0      77.0       73.0       60.0
# Poison     399.0      67.0       75.0       69.0
# Electric   443.0      60.0       69.0       66.0
# Ground     438.0      74.0       96.0       85.0
# Fairy      413.0      74.0       62.0       66.0
