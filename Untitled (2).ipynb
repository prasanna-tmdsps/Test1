# %%
import pandas as pd 
import numpy as np

# %%
titanic_df = pd.read_csv("train.csv")

# %%
total = titanic_df.isnull().sum().sort_values(ascending=False)
percent = ((titanic_df.isnull().sum()/titanic_df.isnull().count())*100).sort_values(ascending=False)
missing_data_df = pd.concat([total,percent],axis=1,keys=['Total', 'Percent'])
missing_data_df
# Out:
#              Total    Percent
# Cabin          687  77.104377
# Age            177  19.865320
# Embarked         2   0.224467
# PassengerId      0   0.000000
# Survived         0   0.000000
# Pclass           0   0.000000
# Name             0   0.000000
# Sex              0   0.000000
# SibSp            0   0.000000
# Parch            0   0.000000
# Ticket           0   0.000000
# Fare             0   0.000000

# %%
titanic_df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#titanic_df["Embarked"].fillna("Absent", inplace = True)

# %%
titanic_df.drop('Cabin', axis=1, inplace=True)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
median_age = titanic_df["Age"].median()

# %%
titanic_df["Age"].fillna(median_age, inplace = True)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df = titanic_df.astype({"Survived":bool, "Pclass": int, "Parch":int})

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
titanic1_df.dtypes
# Out:
# PassengerId      int64
# Survived          bool
# Pclass           int32
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int32
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
titanic_df1 = titanic_df
titanic_df1["Embarked"].fillna("Absent", inplace=True)
titanic_df1[titanic_df1["Embarked"] == "Absent"]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0   Absent
# 829  female  62.0      0      0  113572  80.0   Absent

# %%
titanic_df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', 'Absent'], dtype=object)

# %%
titanic_df = pd.get_dummies(titanic_df, columns=["Embarked"])

# %%
#PassengerId
titanic_df2[titanic_df2["PassengerId"]==62]
# Out:
#     PassengerId  Survived  Pclass                 Name     Sex   Age  SibSp  \
# 61           62         1       1  Icard, Miss. Amelie  female  38.0      0
#
#     Parch  Ticket  Fare  Embarked_Absent  Embarked_C  Embarked_Q  Embarked_S
# 61      0  113572  80.0                1           0           0           0
